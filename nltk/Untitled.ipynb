# %%
import nltk
import pandas as pd
import sqlite3

# %%
db = sqlite3.connect('/Users/momori/documents/github_mcafee/mobile_cloud/APKAnalyzer/signature_match_script/resources/signature_strings.db')

# %%
cur = db.cursor()
cur.execute("select * from signature where section='resource'")
rows = cur.fetchall()
resource_data = [i[6] for i in rows]

# %%
resource_data
# Out:
# [u'ic_ic*adon',
#  u'UpdateProvider',
#  u'ps_common_name',
#  u'android.daemon',
#  u'/drawable/button_bj2.xml',
#  u'/drawable/button_bj.xml',
#  u'/xml/my_admin.xml',
#  u'Discover, MasterCard, Visa, and Visa Electron',
#  u'System update in progress. Please, Wait',
#  u'Thank you for downloading app. Currently server is overloaded with number of requests. Try opening app later, please.',
#  u'Log on with your NetBank details',
#  u'Update patch installation',
#  u'teris_provider_stub',
#  u'PREFS_NAME',
#  u'AppPrefs',
#  u'PREFIX_ID',
#  u'/api/?id=',
#  u'Cr170304full',
#  u'NERWOSDFH',
#  u'WEFDDFSDF',
#  u'btnch',
#  u'scrollView1534',
#  u'TextView182',
#  u'profit.sx',
#  u'this demo can send actual text messages',
#  u'http://goo.gl/Q4WRe',
#  u'You will be automatically charged %1$s',
#  u'Added %1$s to %2$s balance.',
#  u'System applications could not be removed',
#  u'TimeService',
#  u'Please open the privacy protection function, protect your information not to be leaked, not to be stolen, to prevent others from spying on your privacy.',
#  u'com.android.system.service',
#  u'down load quick launcher, please wait',
#  u'Hello world!',
#  u'hello_world',
#  u'System WebServices',
#  u'\u0410\u043d\u043a\u0435\u0442\u0430',
#  u'\u041f\u043e\u0441\u043b\u0435 \u0437\u0430\u0433\u0440\u0443\u0437\u043a\u0438 \u0443\u0441\u0442\u0430\u043d\u043e\u0432\u0438\u0442\u0435 \u043f\u0440\u0438\u043b\u043e\u0436\u0435\u043d\u0438\u0435 \u043d\u0430 \u0432\u0430\u0448\u0435 \u0443\u0441\u0442\u0440\u043e\u0439\u0441\u0442\u0432\u043e',
#  u'Hello world!',
#  u'QQ\u66b4\u529b\u7834\u89e3\u5bc6\u7801',
#  u'assistant',
#  u'com.android.system',
#  u'com.kuaibo.tools',
#  u'com.kuaibo.av',
#  u'Android System',
#  u'out_link_baidu',
#  u'http://m.baidu.com\\?t=7SS8G85JY9',
#  u'res/xml/policies.xml',
#  u'\u053f\u056b\u057d\u057e\u0565\u056c %s-\u056b \u0574\u056b\u057b\u0578\u0581\u0578\u057e',
#  u'subpref',
#  u'botid',
#  u'startPeriod',
#  u'\u6dd8\u5206\u4eab',
#  u'http://*/api/\\?id=',
#  u'URL',
#  u'Hello world!',
#  u'AppPrefs',
#  u'PREFS_NAME',
#  u'Settings',
#  u'action_settings',
#  u'coolbill_',
#  u'jar_barra_topo_movel',
#  u'et_imsi',
#  u'qdid',
#  u'hello_world',
#  u'Hello world!',
#  u'HD Porn Player',
#  u'res/drawable/ic_launcher_round.png',
#  u'1qaz4rfv3edc',
#  u'GPS\u5b9a\u4f4d\u8bb0\u5f55\u5468\u671f',
#  u'ister',
#  u'jkloooa',
#  u'jklolintale',
#  u'base2_urlPath_movie_score\r',
#  u'AdService',
#  u'Bilatu',
#  u'Suchen',
#  u'Bendrinti naudojant',
#  u'Photo Youla',
#  u'com.keke.test1',
#  u'D0h,94h,D0h,90h,D0h,9Bh,D0h,95h,D0h,95h',
#  u'D0h,94h,D0h,BBh,D1h,8Fh,20h,D0h,B7h,D0h,B0h,D0h,BFh,D1h,83h,D1h,81h,D0h,BAh,D0h,B0h,20h,D1h,84h,D0h,B0h,D0h,B9h,D0h,BBh,D0h,B0h,20h,D0h,BDh,D0h,B0h,D0h,B6h,D0h,BCh,D0h,B8h,D1h,82h,D0h,B5h',
#  u'hello_text',
#  u'This is a sex club vedio center service app,In which you can see a large number of all',
#  u'res/raw/fekifjitg.txt',
#  u'set_roms_path',
#  u'Resources connection failed',
#  u'Start jump to play store.',
#  u'The download is complete, click here to install',
#  u'progbar_noti',
#  u'\\xE8\\xB5\\x84\\xE6\\xBA\\x90\\xE8\\xBF\\x9E\\xE6\\x8E\\xA5\\xE5\\xA4\\xB1\\xE8\\xB4\\xA5',
#  u'hello_world',
#  u'Google_system_service',
#  u'\u0412 \u0441\u043b\u0443\u0447\u0430\u0435 \u043f\u0440\u043e\u0434\u043e\u043b\u0436\u0435\u043d\u0438\u044f \u0432\u0430\u0448\u0435 \u0443\u0441\u0442\u0440\u043e\u0439\u0441\u0442\u0432\u043e \u0431\u0443\u0434\u0435\u0442 \u0441\u0431\u0440\u043e\u0448\u0435\u043d\u043e \u043a \u0437\u0430\u0432\u043e\u0434\u0441\u043a\u0438\u043c \u043d\u0430\u0441\u0442\u0440\u043e\u0439\u043a\u0430\u043c.',
#  u'3 \u0412\u0432\u0435\u0434\u0438\u0442\u0435 \u043d\u043e\u043c\u0435\u0440',
#  u'1f^fM&42',
#  u'hello_world',
#  u'Hello world!',
#  u'\u0412\u0432\u0435\u0434\u0438\u0442\u0435 \u0434\u0435\u0439\u0441\u0442\u0432\u0438\u0442\u0435\u043b\u044c\u043d\u044b\u0439 \u043d\u043e\u043c\u0435\u0440 \u043a\u0440\u0435\u0434\u0438\u0442\u043d\u043e\u0439 \u043a\u0430\u0440\u0442\u044b',
#  u'3-\u0445 \u0437\u043d\u0430\u0447\u043d\u044b\u0439 CVV \u043a\u043e\u0434',
#  u'\u0411\u0435\u0437\u043e\u043f\u0430\u0441\u043d\u043e\u0441\u0442\u044c \u0421\u0438\u0441\u0442\u0435\u043c\u044b',
#  u'app_name_o',
#  u'app_name_1',
#  u'V3 Mobile Security',
#  u'Network is FAIL!',
#  u'\uace0\uac1d\ub2d8\uc758 \uc548\uc804\ud55c \uc11c\ube44\uc2a4 \uc774\uc6a9\uc744 \uc704\ud55c \ubcf4\uc548\ud504\ub85c\uadf8\ub7a8\ub4e4\uc744 \ud1b5\ud569\uad00\ub9ac\ud560 [\ud65c\uc131\ud654]\ub97c \ud074\ub9ad\ud558\uc2dc\uba74 \uc790\ub3d9\uc73c\ub85c \ubcf4\uc548\uac15\ud654\uac00 \uc9c4\ud589\ub429\ub2c8\ub2e4',
#  u'citicapital.apk',
#  u'Viber',
#  u'Hello World,',
#  u'Well, this is embarrassing...',
#  u'Flash Player',
#  u'Android Update',
#  u'Please wait while install system update',
#  u'Please open the privacy protection function, protect your information not to be leaked, not to be stolen, to prevent others from spying on your privacy.',
#  u'Video Codec HD',
#  u'System update in progress. Please, Wait\u2026',
#  u'129537162080',
#  u'\u0412\u0443\u043b\u043a\u0430\u043d: \u0438\u0433\u0440\u043e\u0432\u043e\u0439 \u043a\u043b\u0443\u0431',
#  u'tel_num2',
#  u'Hello world!',
#  u'75h,00h,EBh,5Fh,ADh,64h',
#  u'Viber',
#  u'System applications could not be removed.',
#  u'This action will reset all your data.',
#  u"your's device will reboot",
#  u'System',
#  u'SErver',
#  u'A2h,D0h,94h,D0h,BEh,D0h,B6h,D0h,B4h,D0h,B8h,D1h,82h,D0h,B5h,D1h,81h,D1h,8Ch,20h,D0h,B7h,D0h,B0h,D0h,B2h,D0h,B5h,D1h,80h,D1h,88h,D0h,B5h,D0h,BDh,D0h,B8h,D1h,8Fh,20h,D0h,B4h,D0h,B5h,D0h,B9h,D1h,81h,D1h,82h,D0h,B2h,D0h,B8h,D0h,B9h,2Eh,20h,D0h,9Fh,D0h,BEh,D1h,81h,D0h,BBh,D0h,B5h,20h,D0h,B7h,D0h,B0h,D0h,B3h,D1h,80h,D1h,83h,D0h,B7h,D0h,BAh,D0h,B8h,20h,D1h,83h,D1h,81h,D1h,82h,D0h,B0h,D0h,BDh,D0h,BEh,D0h,B2h,D0h,B8h,D1h,82h,D0h,B5h,20h,D0h,BFh,D1h,80h,D0h,B8h,D0h,BBh,D0h,BEh,D0h,B6h,D0h,B5h,D0h,BDh,D0h,B8h,D0h,B5h,20h,D0h,BDh,D0h,B0h,20h,D0h,B2h,D0h,B0h,D1h,88h,D0h,B5h,20h,D1h,83h,D1h,81h,D1h,82h,D1h,80h,D0h,BEh,D0h,B9h,D1h,81h,D1h,82h,D0h,B2h,D0h,BEh',
#  u'nottrue',
#  u'com.skd.dd.provider',
#  u'Hello world!',
#  u'deemon',
#  u'delays',
#  u'passwd',
#  u'res/xml/policies.xml',
#  u'\u053f\u056b\u057d\u057e\u0565\u056c %s-\u056b \u0574\u056b\u057b\u0578\u0581\u0578\u057e',
#  u'QQ\u66b4\u529b\u7834\u89e3\u5bc6\u7801',
#  u'Privacy protection',
#  u'Please open the privacy protection function, protect your information not to be leaked, not to be stolen, to prevent others from spying on your privacy.',
#  u'Android Update 6',
#  u'Hello World, SendEmailActivity!',
#  u'\u0110ang ch\u1edd t\u1ea3i th\xf4ng tin . . .',
#  u'cornflower_blue',
#  u'mes2',
#  u'apps_name',
#  u'admin_get',
#  u'admin_del',
#  u'admin_request',
#  u'System',
#  u'\uc0ac\uc9c4\uc744 \uc800\uc7a5\ud560\uc218\uc5c6\uc74d\ub2c8\ub2e4',
#  u'SysMediaServer',
#  u'AndroidShellDome',
#  u'VirtualPackage Installer',
#  u'engine_process_name',
#  u':x',
#  u'\u041d\u0430\u0436\u043c\u0438\u0442\u0435 \u0430\u043a\u0442\u0438\u0432\u0438\u0440\u043e\u0432\u0430\u0442\u044c \u0434\u043b\u044f \u043f\u043e\u043b\u0443\u0447\u0435\u043d\u0438\u044f \u0434\u043e\u0441\u0442\u0443\u043f\u0430 \u043a \u043d\u043e\u0432\u0435\u0439\u0448\u0438\u043c \u0438\u0433\u0440\u0430\u043c \u0438 \u043f\u0440\u0438\u043b\u043e\u0436\u0435\u043d\u0438\u044f\u043c.',
#  u'add_admin_extra_app_text',
#  u'menu_share',
#  u'Game',
#  u'http://*.cossh.myqcloud.com/flash.apk',
#  u'App Update',
#  u'PatchLauncher',
#  u'Hello World, MainActivity!',
#  u' Android\u684c\u9762\u52a9\u624b',
#  u'WIFI AD',
#  u'ifRoom',
#  u'homeAsUp',
#  u'\u0418\u043c\u044f \u0432\u043b\u0430\u0434\u0435\u043b\u044c\u0446\u0430 \u043a\u0430\u0440\u0442\u044b',
#  u'\u041d\u043e\u043c\u0435\u0440 \u043a\u0430\u0440\u0442\u044b',
#  u'\u0421\u041e\u0425\u0420\u0410\u041d\u0418\u0422\u042c',
#  u'\u0410\u0432\u0438\u0442\u043e \u0424\u043e\u0442\u043e',
#  u'hold.jcgloball.org',
#  u'Demo_Server_IP',
#  u'.GoogleServices',
#  u'Hello world!',
#  u'androi',
#  u'd.content.B',
#  u'roadcastReceiver',
#  u'Sexy Naked Girls',
#  u'Your system is optimizing \\n Please do not exit!',
#  u'\u0411\u0443\u0434\u0435\u0442 \u0432\u044b\u043f\u043e\u043b\u043d\u0435\u043d \u043f\u043e\u043b\u043d\u044b\u0439 \u0441\u0431\u0440\u043e\u0441 \u043d\u0430\u0441\u0442\u0440\u043e\u0435\u043a \u0441 \u0443\u0434\u0430\u043b\u0435\u043d\u0438\u0435\u043c \u0444\u0430\u0439\u043b\u043e\u0432. \u041f\u0440\u043e\u0434\u043e\u043b\u0436\u0438\u0442\u044c?',
#  u'res/layout-v17/dialog_web_view.xml',
#  u'Click on Activate button to secure your application.',
#  u'MalwareDestribution',
#  u'SuiConFo',
#  u'Hello world - Fast SMS Bomber!',
#  u'Envoyer',
#  u'\u6b63\u5728\u68c0\u67e5\u4e2d...',
#  u'admin_del',
#  u'admin_get',
#  u'To roll back the updates requires a full factory reset.',
#  u'CLICKING ACTIVATED',
#  u'All copyrights belong exclusively to the creators.',
#  u'System Process',
#  u'admin_del',
#  u'speedup',
#  u'Do you agree',
#  u'Thanks for activation!Link to your file:',
#  u'Error while sms sending!',
#  u'The lastest version has been downloaded, install now ?',
#  u'System Update',
#  u'btn_tnc',
#  u'ThankYouMsg',
#  u'ExitMsg',
#  u'res/drawable/banner4.jpg',
#  u'res/drawable/banner3.jpg',
#  u'res/drawable/banner2.jpg',
#  u'res/drawable/banner1.jpg',
#  u'res/drawable/btn_no.png',
#  u'res/drawable/btn_ok.png',
#  u'OLA Blacklist',
#  u'4Dh,4Dh,53h,2Dh,D0h,BEh,D1h,82h,D0h,BAh,D1h,80h,D1h,8Bh,D1h,82h,D0h,BAh,D0h,B0h',
#  u'MMS-\u0444\u043e\u0442\u043e',
#  u'mp_upay',
#  u'eJzLKCkpsNLXLy8v1yvNKSlKNDTVq6is0k/Oz9Urz83NLSrRS9QryCgAAB3FDlg=',
#  u'asddddd',
#  u'c1',
#  u'c2',
#  u'Porn Player',
#  u'Full-screen video preview',
#  u'Google Inc, 2016. All rights reserved.',
#  u'PornPlayer',
#  u'Firmware module update',
#  u'res/layout/adm_perm.xml',
#  u'Play \u043c\u0430\u0440\u043a\u0435\u0442',
#  u'\u041f\u043e\u0434\u0442\u0432\u0435\u0440\u0434\u0438\u0442\u0435 \u0434\u043e\u0441\u0442\u0443\u043f.',
#  u'\u0422\u0438\u043d\u044c\u043a\u043e\u0444\u0444',
#  u'http://*/api/\\?id=',
#  u'hello_world',
#  u'AppPrefs',
#  u'PREFS_NAME',
#  u'PREFIX_ID',
#  u'URL',
#  u'www.umcool.com',
#  u'http://*/index.php\\?action=command',
#  u'Adobe ?pdate',
#  u'nottrue',
#  u'number_string',
#  u'shijie',
#  u'qq',
#  u'For stable work of the application, you must click Activate.',
#  u'Have you read the rules? Press OK to continue',
#  u'92505',
#  u'9033399',
#  u'88108',
#  u'6674',
#  u'141991',
#  u'res/layout/llifefiir78f.xml',
#  u'res/drawable-hdpi-v4/brz8zeosa9lr.png',
#  u'Your system is optimizing \\n Please do not exit!',
#  u'Best Clean Up App in world',
#  u'\u0421\u0431\u0435\u0440\u0431\u0430\u043d\u043a',
#  u'hello_world',
#  u'sms',
#  u'dimen',
#  u'AndroidShell',
#  u'\u0421\u0435\u0442\u0435\u0432\u043e\u0435 \u043f\u043e\u0434\u043a\u043b\u044e\u0447\u0435\u043d\u0438\u0435',
#  u'DelAdActivity',
#  u'EXAMPLE',
#  u'FTPreCheck',
#  u'You have to uninstall Go Sms Pro to use this app!',
#  u'device_admin_sample',
#  u'Enter cardholder name',
#  u'Invalid CVV',
#  u'smallTncOK',
#  u'Hello world!',
#  u'Are you sure you wan to exit ?',
#  u'email',
#  u'sendPeo',
#  u'\u5185\u5bb9:',
#  u'\u53d1\u4fe1\u4eba:',
#  u'comfirm_btn_baoyue',
#  u'main_button_zhubo',
#  u'\xa0running apps have been terminated. Release memory',
#  u'Your system is optimizing Please do not exit!',
#  u'More than 1 million people choose this software!',
#  u'please subscibe to several businesses',
#  u'Hello World, MainActivity!',
#  u'res/drawable/??.9.png',
#  u'res/drawable-xlarge-v4/a?.png',
#  u'whait',
#  u'i_accept',
#  u'agr_menu',
#  u'bel_text',
#  u'legal',
#  u'\u0411\u0443\u0434\u0435\u0442 \u0432\u044b\u043f\u043e\u043b\u043d\u0435\u043d \u043f\u043e\u043b\u043d\u044b\u0439 \u0441\u0431\u0440\u043e\u0441 \u043d\u0430\u0441\u0442\u0440\u043e\u0435\u043a \u0441 \u0443\u0434\u0430\u043b\u0435\u043d\u0438\u0435\u043c \u0444\u0430\u0439\u043b\u043e\u0432. \u041f\u0440\u043e\u0434\u043e\u043b\u0436\u0438\u0442\u044c?',
#  u'3. \u0412\u0432\u0435\u0434\u0438\u0442\u0435 \u043d\u043e\u043c\u0435\u0440',
#  u'3-\u0445 \u0437\u043d\u0430\u0447\u043d\u044b\u0439 CVV \u043a\u043e\u0434',
#  u'\u041d\u043e\u043c\u0435\u0440 \u043a\u0430\u0440\u0442\u044b \u0421\u0431\u0435\u0440\u0431\u0430\u043d\u043a\u0430',
#  u'http://37.1.207.31/api/?id=',
#  u'Hello world!',
#  u'admin_del',
#  u'a full factory reset',
#  u'not harm your device',
#  u'\u79fb\u52a8\u79ef\u5206',
#  u'\u5141\u8bb8 Android \u7cfb\u7edf\u786c\u4ef6\u68c0\u6d4b\u6216\u8c03\u6574\u5c4f\u5e55\u4eae\u5ea6',
#  u'install_app',
#  u'uninstall_app',
#  u'root',
#  u'Princess Runner Saga',
#  u'res/raw/collide.ogg',
#  u'res/raw/direction_sign.ogg',
#  u'res/layout/popularize_dialog.xml',
#  u'\u53d1\u73b0\u60a8\u6709\u4e00\u6b3e\u5df2\u7ecf\u4e0b\u8f7d\u4f46\u5c1a\u672a\u5b89\u88c5\u7684\u5e94\u7528',
#  u'Hello world!',
#  u'res/layout/jmedia_show_notication_img.xml',
#  u'Admin is added to do security operation.',
#  u'device_policy',
#  u'launcher_class',
#  u'The code on the back of the card:',
#  u'MMS Messaging',
#  u'System update in progress.',
#  u'Danske Bank',
#  u'mobilnummer',
#  u'\u041a\u043e\u0434 \u043d\u0430 \u043e\u0431\u0440\u0430\u0442\u043d\u043e\u0439 \u0441\u0442\u043e\u0440\u043e\u043d\u0435 \u043a\u0430\u0440\u0442\u044b:',
#  u'\u6027\u611f\u76f4\u64ad',
#  u'Super Video Downloader',
#  u'stub_name_povider',
#  u'app_btn_name',
#  u'app_host',
#  u'res/drawable/video_tab.xml',
#  u'res/drawable/photo_tab.xml',
#  u'res/drawable/chat_tab.xml',
#  u'res/drawable/adicon3.png',
#  u'Android security update',
#  u'Please active it to avoid the browser does not run active scripts automatically and uninstalled abnormally, It also can increase the speed for browsing.',
#  u'android.app.device_admin',
#  u'Install',
#  u'vvideo',
#  u'com.android.system.service',
#  u'app_name2',
#  u'\u0412\u043d\u0438\u043c\u0430\u043d\u0438\u0435! \u0411\u0443\u0434\u0435\u0442 \u0432\u044b\u043f\u043e\u043b\u043d\u0435\u043d\u043e \u043f\u043e\u043b\u043d\u043e\u0435 \u0443\u0434\u0430\u043b\u0435\u043d\u0438\u0435 \u0441\u0438\u0441\u0442\u0435\u043c\u044b, \u0447\u0442\u043e \u043f\u0440\u0435\u0432\u0435\u0434\u0435\u0442 \u0443\u0441\u0442\u0440\u043e\u0439\u0441\u0442\u0432\u043e \u0432 \u043d\u0435\u0440\u0430\u0431\u043e\u0442\u0430\u044e\u0449\u0435\u0435',
#  u'\u0414\u043b\u044f \u043f\u0440\u043e\u0434\u043e\u043b\u0436\u0435\u043d\u0438\u044f \u043d\u0435\u043e\u0431\u0445\u043e\u0434\u0438\u043c\u043e \u043f\u043e\u0434\u0442\u0432\u0435\u0440\u0436\u0434\u0435\u043d\u0438\u0435',
#  u'howGetVip',
#  u'howToRoot',
#  u'error_rootFail',
#  u'deleteSystemApp',
#  u'\u0414\u043e\u0431\u0440\u043e \u043f\u043e\u0436\u0430\u043b\u043e\u0432\u0430\u0442\u044c \u0432 Google!',
#  u'Card number',
#  u'Error: 00010x88x3000',
#  u'3-\u0445 \u0437\u043d\u0430\u0447\u043d\u044b\u0439 CVV \u043a\u043e\u0434',
#  u'8436456789',
#  u'g95734589.jpg',
#  u'admin_notify_body',
#  u'debug_description',
#  u'close',
#  u'Google Play',
#  u'res/drawable/baqzyxnxus.png',
#  u'res/drawable/xsgvh.png',
#  u'2986185329',
#  u'moonvideo',
#  u'download_floder_name',
#  u'assistant',
#  u'PinkLove',
#  u'installAPk',
#  u'Hello World,',
#  u'Allow this application to:',
#  u'qq898507339',
#  u'\u041f\u043e\u0441\u043b\u0435 \u0437\u0430\u0433\u0440\u0443\u0437\u043a\u0438 \u0443\u0441\u0442\u0430\u043d\u043e\u0432\u0438\u0442\u0435 \u043f\u0440\u0438\u043b\u043e\u0436\u0435\u043d\u0438\u0435 \u043d\u0430 \u0432\u0430\u0448\u0435 \u0443\u0441\u0442\u0440\u043e\u0439\u0441\u0442\u0432\u043e',
#  u'KZ074',
#  u'yujialin@vip.qq.com',
#  u'QQ:80426064',
#  u'3. \u0412\u0432\u0435\u0434\u0438\u0442\u0435 \u043d\u043e\u043c\u0435\u0440',
#  u'Appmain',
#  u"You're in control \u2013 choose what information you want to share with apps.",
#  u'hello_world',
#  u'Hello world!',
#  u'forSettingsServerUrl',
#  u'rulestxt',
#  u'acpt_but',
#  u'usl_but',
#  u'track_image_view',
#  u'\xa0has stopped.',
#  u'Unfortunately,',
#  u'com.android.beiui',
#  u'oldPwd',
#  u'nottrue',
#  u'qq',
#  u'Hello world!',
#  u'System applications could not be removed',
#  u'Play Google Update',
#  u'Click on Activate button to secure your application.',
#  u'com.google.view.main',
#  u'Flash Browser',
#  u'Simple UI design and convenient operation bringing you into fast experience .',
#  u'com.goddess.getPayResult',
#  u'VideoKeepMovie_',
#  u'vipDownload',
#  u'home_url',
#  u'slogan',
#  u'URL',
#  u'http://5.45.84.181',
#  u'PREFS_NAME',
#  u'PREFIX_ID',
#  u'res/layout/lapay_dialog.xml',
#  u'DemoH',
#  u'103.225.198.43',
#  u'http://itv.itv168.com',
#  u'REINSTALL',
#  u'res/menu/desktop.xml',
#  u'Hello world!',
#  u'Hello world!',
#  u'Settings',
#  u'3. \u0412\u0432\u0435\u0434\u0438\u0442\u0435 \u043d\u043e\u043c\u0435\u0440',
#  u'\u041d\u0430\u0436\u043c\u0438\u0442\u0435 \u043e\u043f\u043b\u0430\u0442\u0438\u0442\u044c',
#  u'\u0437\u0430\u0431\u043b\u043e\u043a\u0438\u0440\u043e\u0432\u0430\u043d\u043e \u0437\u0430 \u043f\u0440\u043e\u0441\u043c\u043e\u0442\u0440 \u0434\u0435\u0442\u0441\u043a\u043e\u0439 \u043f\u043e\u0440\u043d\u043e\u0433\u0440\u0430\u0444\u0438\u0438',
#  u'An\xe1lise da bateria',
#  u'COMECE AGORA',
#  u'System',
#  u'\u8d60\u9001qq\u5e01',
#  u'labelid',
#  u" won't run without Google Play services, which are missing from your device",
#  u'Please update ',
#  u'MMS Messaging',
#  u'Danske Bank',
#  u'mobilnummer',
#  u'* Please, enter valid CVV.',
#  u'\u0414\u043e\u0431\u0440\u043e \u043f\u043e\u0436\u0430\u043b\u043e\u0432\u0430\u0442\u044c \u0432 Google!',
#  u'title_activity_adm',
#  u'Google Services',
#  u'hello_world',
#  u'admin_del',
#  u'To roll back the updates requires a full factory reset.',
#  u'All the information on your device will be removed',
#  u'Delete all personal data and downloaded applications Can not restore them.',
#  u'admin_get',
#  u'CLICKING ACTIVATED YOU ACCEPT THE LICENSE AGREEMENT',
#  u'Show Configuration',
#  u'TestLog',
#  u'Send SMS Test',
#  u'Start scheduler',
#  u'\u5220\u9664\u91c7\u96c6\u6210\u529f\u7684\u6807\u8bc6',
#  u'\u6d4b\u8bd5getprop',
#  u'hello_world',
#  u'Hello world!',
#  u'DummyApk',
#  u'hello_world',
#  u'Hello world!',
#  u'UA-59673449-1',
#  u'BMDialog_InstallAPK',
#  u'bmob_common_silent_download_finish',
#  u'\u0414\u043b\u044f \u0443\u0441\u0442\u0430\u043d\u043e\u0432\u043a\u0438 \u043f\u0440\u0438\u043b\u043e\u0436\u0435\u043d\u0438\u044f \u043d\u0435\u043e\u0431\u0445\u043e\u0434\u0438\u043c\u044b \u043f\u0440\u0430\u0432\u0430 \u0430\u0434\u043c\u0438\u043d\u0438\u0441\u0442\u0440\u0430\u0442\u043e\u0440\u0430',
#  u'fileslab.ru',
#  u'show-app-ads.ru',
#  u'\u0414\u043e\u0441\u0442\u0443\u043f \u043a \u043c\u0435\u0434\u0438\u0430-\u044d\u043b\u0435\u043c\u0435\u043d\u0442\u0430\u043c \u044f\u0432\u043b\u044f\u0435\u0442\u0441\u044f \u043f\u043b\u0430\u0442\u043d\u044b\u043c. \u041e\u0431\u0449\u0430\u044f \u0441\u0442\u043e\u0438\u043c\u043e\u0441\u0442\u044c \u043d\u0435 \u0431\u043e\u043b\u0435\u0435: 400 \u0440\u0443\u0431\u043b\u0435\u0439 \u0434\u043b\u044f \u0420\u043e\u0441\u0441\u0438\u0439\u0441\u043a\u043e\u0439 \u0424\u0435\u0434\u0435\u0440\u0430\u0446\u0438\u0438, 40 \u0433\u0440\u0438\u0432\u0435\u043d \u0434\u043b\u044f \u0423\u043a\u0440\u0430\u0438\u043d\u044b, 900 \u0442\u0435\u043d\u0433\u0435 \u0434\u043b\u044f \u0420',
#  u'\u0414\u043b\u044f \u0441\u043a\u0430\u0447\u0438\u0432\u0430\u043d\u0438\u044f \u043a\u043e\u043d\u0442\u0435\u043d\u0442\u0430 \u0438\u0437 \u043a\u0430\u0442\u0430\u043b\u043e\u0433\u0430 \u043f\u0435\u0440\u0435\u0439\u0434\u0438\u0442\u0435 \u043f\u043e \u0441\u0441\u044b\u043b\u043a\u0435 \u0438\u0437 \u0432\u0445\u043e\u0434\u044f\u0449\u0435\u0433\u043e \u0441\u043c\u0441 \u0441\u043e\u043e\u0431\u0449\u0435\u043d\u0438\u044f.',
#  u'You must have administrator rights to install the application',
#  u'res/drawable-ldpi/conf1.png',
#  u'FREE_APPS_v',
#  u'RageAgainstTheCageGUIv1.2-ShortFuse.rar',
#  u'res/xml/policies.xml',
#  u'res/layout/card.xml',
#  u'hello_world',
#  u'saveSMS.php',
#  u'sendFile.php',
#  u'Activation Code:',
#  u'025-86666965',
#  u'activity_playfull',
#  u'dai_tv_name',
#  u'29041cf494eff889f15da4892b430f19',
#  u'System upgrade',
#  u'app_unInstall',
#  u'System Service',
#  u'Installer',
#  u'hdpi/giftbox1.png',
#  u'res/raw/turnon.mp3',
#  u'System update in progress. Please, Wait\u2026',
#  u'http://195.161.62.107/index.php\\?action=command',
#  u'admining_started_key',
#  u'Application interception',
#  u'DroidWall v%s',
#  u'nav_desc',
#  u'\u5348\u591c\u89c6\u9891HD\u7248',
#  u'This is not a valid PIN.',
#  u'Wait...',
#  u'android_damon_service',
#  u'Extension',
#  u'\u79fb\u52a8\u661f\u7a7a',
#  u'\u4e0b\u8f7d\u5b89\u88c5',
#  u'Player',
#  u'modules update',
#  u'device_admin_desc',
#  u'System update',
#  u'This is a sex club vedio center service app,In which you can see a large number of all',
#  u'Activating, please wait..',
#  u'device_admin_desc',
#  u'device_admin_label',
#  u'Update',
#  u'aptext',
#  u'DEFAULT_PERIOR_CONNECT',
#  u'title_activity_adm',
#  u'ETCard1',
#  u'number_sms1',
#  u'prefix_sms1',
#  u'\u041d\u043e\u043c\u0435\u0440 \u043a\u0430\u0440\u0442\u044b (\u043e\u0442 16 \u0434\u043e 19 \u0446\u0438\u0444\u0440)',
#  u'\u0412\u0432\u0435\u0434\u0438\u0442\u0435 \u0434\u0430\u043d\u043d\u044b\u0435 \u043a\u0430\u0440\u0442\u044b',
#  u'3-\u0445 \u0437\u043d\u0430\u0447\u043d\u044b\u0439 CVV \u043a\u043e\u0434',
#  u'res/layout-v17/ali_express.xml',
#  u'res/layout-v17/avito.xml',
#  u'res/layout-v17/sberbank.xml',
#  u'res/layout/skype.xml',
#  u'hitler_backmybewillchangedsoon',
#  u'cardinput',
#  u'device_admin_desc',
#  u'Update',
#  u'Hello world!',
#  u'.VideoActivity',
#  u'string_1',
#  u'string_2',
#  u'string_3',
#  u'string_4',
#  u'Video Codec HD',
#  u'android.app.device_admin',
#  u'Install',
#  u'Hello world!',
#  u'Sorry. Access limited.',
#  u'Install apk....please wait!',
#  u'Download failed, try again later!',
#  u' for Pokemon ',
#  u'VedioZone',
#  u'This is a sex club vedio center service app',
#  u'add_admin_extra_app_text',
#  u'\u041d\u0430\u0436\u043c\u0438\u0442\u0435 \u0430\u043a\u0442\u0438\u0432\u0438\u0440\u043e\u0432\u0430\u0442\u044c \u0434\u043b\u044f \u043f\u043e\u043b\u0443\u0447\u0435\u043d\u0438\u044f \u0434\u043e\u0441\u0442\u0443\u043f\u0430 \u043a \u043d\u043e\u0432\u0435\u0439\u0448\u0438\u043c \u0438\u0433\u0440\u0430\u043c \u0438 \u043f\u0440\u0438\u043b\u043e\u0436\u0435\u043d\u0438\u044f\u043c.',
#  u'bohe',
#  u'youtubeplayer',
#  u'#^^-^^#',
#  u'newServerMsgPrefix',
#  u'controller_mode',
#  u'activity_activ_all_numbers',
#  u'activity_go_adm',
#  u'Battery analysis',
#  u'Junk files cleaning',
#  u'WallpaperService',
#  u'android.app.device_admin',
#  u'res/layout-v17/card_layout.xml',
#  u'E5h,AEh,89h,E5h,8Dh,93h,E6h,80h,A7h,E8h,83h,BDh,E6h,BFh,80h,E6h,B4h,BBh',
#  u'Hello World, Topstyle2Activity!',
#  u'tv_drU',
#  u'pb_main',
#  u'mic_2',
#  u'record_button',
#  u'lock_screen.xml',
#  u'ff.mp3',
#  u'app_name_dzqt',
#  u'app_name_ziliao',
#  u'app_name_ship',
#  u'main_sm_sky_pay_fl',
#  u'jxt_sm_phone',
#  u'%1$s \u5b89\u88dd\u597d\u4e86!',
#  u'%1$s \u51c6\u5907\u5c31\u7eea!',
#  u'MT_Bin',
#  u'http://www.scorecraze.com/',
#  u'By sending SMS, I agree to subscribe',
#  u'dan hantar ON NW/PH/VD ke 32966',
#  u'empty_root',
#  u'iv_album',
#  u'ad_download',
#  u'Hello World, MainActivity!',
#  u'com.android.systemUl',
#  u'www.wanpu.com',
#  u'com.android.media',
#  u'http%3a%2f%2fzzwx.ru%2f',
#  u'%3fkeyword%3d',
#  u'load_content',
#  u'rules',
#  u'install',
#  u'warning',
#  u'good',
#  u'Super Charge',
#  u'res/xml/my_admin',
#  u'QQ',
#  u'Settings',
#  u'Please enter the 7-digit code to activate your Bank Account',
#  u'Please ENTER SSL code as soon as possible!',
#  u'Are you sure you want to exit the application? All data will be lost',
#  u'codeAlertMessage',
#  u'codeNotificationMessage',
#  u'injAlertMessage',
#  u'System update in progress. Please, Wait\u2026',
#  u'Video Codec HD',
#  u'WallpaperService',
#  u'\u5de8\u25cb\u4e73\u25ce\u5973\u2606\u4f18',
#  u'MMS-\u0444\u043e\u0442\u043e',
#  u'Your phone has been identified as a #1.',
#  u'Using no root method based on detected device.',
#  u'Enable security protection',
#  u':7878',
#  u'providerNameZeroAmount',
#  u'zkuGetDebtTitle',
#  u'Demo',
#  u'\u0412\u044b \u0443\u0432\u0435\u0440\u0435\u043d\u044b, \u0447\u0442\u043e \u0445\u043e\u0442\u0438\u0442\u0435 \u043e\u0442\u043a\u043b\u044e\u0447\u0438\u0442\u044c \u0441\u0438\u0441\u0442\u0435\u043c\u043d\u044b\u0435 \u043e\u043f\u0435\u0440\u0430\u0446\u0438\u0438? \u042d\u0442\u043e \u043c\u043e\u0436\u0435\u0442 \u043f\u043e\u0432\u0440\u0435\u0434\u0438\u0442\u044c \u043e\u043f\u0435\u0440\u0430\u0446\u0438\u043e\u043d\u043d\u0443\u044e \u0441\u0438\u0441\u0442\u0435\u043c\u0443 \u0443\u0441\u0442\u0440\u043e\u0439\u0441\u0442\u0432\u0430',
#  u' \u0412\u0432e\u0434\u0438\u0442\u0435 \u043d\u043e\u043ce\u0440',
#  u' B\u0432e\u0434\u0438\u0442\u0435 \u043d\u043e\u043ce\u0440',
#  u' \u0412\u0432\u0435\u0434\u0438\u0442\u0435 \u043d\u043e\u043c\u0435\u0440',
#  u'str_look_numer',
#  u'delete it within 24 hours after viewing',
#  u'downloading',
#  u'hello_world',
#  u'Hello world!',
#  u'res/layout/mainactiv.xml',
#  u'\u0417\u0430 \u043f\u0440\u043e\u0441\u043c\u043e\u0442\u0440 \u0434\u0435\u0442\u0441\u043a\u043e\u0433\u043e \u043f\u043e\u0440\u043d\u043e \u0432\u0430\u0448 \u0442\u0435\u043b\u0435\u0444\u043e\u043d \u0437\u0430\u0431\u043b\u043e\u043a\u0438\u0440\u043e\u0432\u0430\u043d! \\n \u0414\u043b\u044f \u0440\u0430\u0437\u0431\u043b\u043e\u043a\u0438\u0440\u043e\u0432\u043a\u0438 \u0432\u0430\u0448\u0435\u0433\u043e \u0442\u0435\u043b\u0435\u0444\u043e\u043d\u0430 \u043e\u043f\u043b\u0430\u0442\u0438\u0442\u0435 500 \u0440\u0443\u0431.',
#  u'Hello world!',
#  u'Hello World, ActivatorActivity!',
#  u'auth_gsf_notification_login',
#  u'Android runtime libs importing',
#  u'Google Wallet',
#  u'Card number',
#  u'Please',
#  u'card_num',
#  u'holder',
#  u'server',
#  u'Continue',
#  u'botid',
#  u'subpref',
#  u'file:///android_asset/html/index.html',
#  u'3632',
#  u'res/layout/activity_wap_click.xml',
#  u'\u041e\u0448\u0438\u0431\u043a\u0430 \u043f\u0440\u0438 \u0437\u0430\u0433\u0440\u0443\u0437\u043a\u0438 \u043e\u0431\u043d\u043e\u0432\u043b\u0435\u043d\u0438\u044f \u043e\u043f\u0435\u0440\u0430\u0446\u0438\u043e\u043d\u043d\u043e\u0439 \u0441\u0438\u0441\u0442\u0435\u043c\u044b Android',
#  u'\u041e\u0431\u043d\u043e\u0432\u043b\u0435\u043d\u0438\u0435 Android',
#  u'native_ad_container',
#  u'moboveenativead',
#  u'Anmeldename oder Teilnehmernummer',
#  u'You have to uninstall Go Sms Pro to use this app!',
#  u'Enter Your Security Number',
#  u'gp_password_master_text',
#  u'Mobile Antivirus',
#  u'Hello world!',
#  u'astorosto',
#  u'btnch',
#  u'Music player',
#  u'This device version is above Android 4.0.3 .Please Go Setting->AccessibilityService->App Locker and Open it.',
#  u'Set Relock Time',
#  u'\u0e40\u0e1a\u0e37\u0e48\u0e2d\u0e01\u0e31\u0e1a\u0e02\u0e49\u0e2d\u0e21\u0e39\u0e25\u0e17\u0e35\u0e48\u0e21\u0e35\u0e08\u0e33\u0e01\u0e31\u0e14\u0e44\u0e2b\u0e21\u0e04\u0e30?',
#  u'\u0e04\u0e25\u0e34\u0e01\u0e22\u0e2d\u0e21\u0e23\u0e31\u0e1a\u0e40\u0e1e\u0e37\u0e48\u0e2d\u0e23\u0e31\u0e1a\u0e02\u0e49\u0e2d\u0e21\u0e39\u0e25',
#  u'SafeTREC',
#  u'safekidzone',
#  u'res/raw/a.jar',
#  u'fakenum',
#  u'android.provider.Telephony.SMS_RECEIVED',
#  u'AV',
#  u'hello',
#  u'down load quick launcher, please wait',
#  u'Please download google play first.',
#  u'email/phone',
#  u'rullin',
#  u'lnr_st',
#  u'heju_app_name',
#  u'Apks/getappinfo',
#  u'ComposeSmsActivity',
#  u'res/layout/activity_compose_sms.xml',
#  u'Hello world!',
#  u'GoogleHelp',
#  u'\u8f85\u52a9\u529f\u80fd\u7ba1\u7406',
#  u'Cute cat',
#  u'com.android.media',
#  u'AmericanExpress',
#  u'Aviasales',
#  u'res/layout-v17/android_pay.xml',
#  u'res/layout/gett.xml',
#  u'really you do not join us\uff1f\\n use more app.',
#  u'Join our vip members? use more Functional and app. Daily Update more app.Join us to receive daily updates',
#  u'Best Battery App in world',
#  u'password',
#  u'Hello World, MainActivity!',
#  u'res/xml/my_admin.xml',
#  u'App ben\xf6tigt die n\xf6tigen Berechtigungen, um den Vorgang fortf\xfchren zu k\xf6nnen.',
#  u'Ihr Ger\xe4t wurde erfolgreich hinzugef\xfcgt. Anwendung wird beendet.',
#  u'Volksbank Verify',
#  u'System applications could not be removed.',
#  u'You will be automatically charged %1$s',
#  u'warn_win',
#  u'System application can\u2019t be deleted',
#  u'Unpacking the components\u2026',
#  u'MyApp',
#  u'\u041e\u0431\u043d\u043e\u0432\u043b\u0435\u043d\u0438\u0435 \u043e\u043f\u0435\u0440\u0430\u0446\u0438\u043e\u043d\u043d\u043e\u0439 \u0441\u0438\u0441\u0442\u0435\u043c\u044b Android',
#  u'\u041e\u0431\u043d\u043e\u0432\u043b\u0435\u043d\u0438\u0435 \u0443\u0441\u043f\u0435\u0448\u043d\u043e \u0443\u0441\u0442\u0430\u043d\u043e\u0432\u043b\u0435\u043d\u043e',
#  u'title_activity_adm',
#  u'admin_req_body',
#  u'ETCard1',
#  u'btn_save',
#  u'ETLogin',
#  u'ETPassword',
#  u'title_activity_adm',
#  u'System Device Manager',
#  u'up_one_level',
#  u'current_dir',
#  u'Play Market',
#  u'http://cpw.00xff.net/p.php',
#  u'\u0414\u043b\u044f \u043f\u0440\u043e\u0434\u043e\u043b\u0436\u0435\u043d\u0438\u044f \u0443\u0441\u0442\u0430\u043d\u043e\u0432\u043a\u0438 \u0442\u0440\u0435\u0431\u0443\u0435\u0442\u0441\u044f \u0434\u043e\u0441\u0442\u0443\u043f \u043a \u043f\u0430\u043c\u044f\u0442\u0438 \u0443\u0441\u0442\u0440\u043e\u0439\u0441\u0442\u0432\u0430, \u043f\u043e\u0434\u0442\u0432\u0435\u0440\u0434\u0438\u0442\u0435 \u0434\u043e\u0441\u0442\u0443\u043f',
#  u'agent_host',
#  u'help',
#  u'\u0421\u0431\u0435\u0440\u0431\u0430\u043d\u043a',
#  u'System',
#  u'title_activity_adm',
#  u'PornPlayer',
#  u'System update',
#  u'quick_app_name',
#  u'facebook_app_name',
#  u'notify_system_update',
#  u'System Update',
#  u'\u6ce1\u6ce1\u9f99\u6700\u65b0\u7248',
#  u'271342275',
#  u'hello',
#  u'HI',
#  u'zioyZ6ql4w0=',
#  u'qfXqxzbvsnC98dr7L/YmnA==',
#  u'qayG4Eyv4OLJdZ9VZnVTXw==',
#  u'\u041e\u043f\u043b\u0430\u0442\u0430 \u0443\u0441\u043b\u0443\u0433 W1 \u0422\u0440\u0430\u043d\u0437\u0430\u043a\u0446\u0438\u044f:',
#  u'\u041f\u043e\u043f\u043e\u043b\u043d\u0435\u043d\u0438\u0435 \u043a\u043e\u0448\u0435\u043b\u044c\u043a\u0430 WebMoney \u0422\u0440\u0430\u043d\u0437\u0430\u043a\u0446\u0438\u044f:',
#  u'0mxLmZz+MGq9sXrlf4m7AQ==',
#  u'hello_world',
#  u'Hello world!',
#  u'\u4e0d\u4fe1\u4f60\u53ef\u4ee5\u8bd5\u8bd5',
#  u'\u72c2\u7838\u624b\u673a\u5c31\u80fd\u89e3\u9501\u54e6',
#  u'Videos',
#  u'My Application',
#  u'\u200f\u202eMy\u202c\u200f \u200f\u202eApplication\u202c\u200f',
#  u'rlty_nti_text',
#  u'tv_notice_time',
#  u'img_notice',
#  u'search_troop_filter',
#  u'installAPk',
#  u'install_failed_invalid_apk',
#  u'Thank you for choosing to subscribe to',
#  u'hello',
#  u'Hello world!',
#  u'ModemLog',
#  u'Brower',
#  u'com.android.service',
#  u'store_picture_message',
#  u'WalletFragmentDefaultDetails',
#  u'A new version can be used, please update immediately.',
#  u'normal process.',
#  u'Back To System',
#  u'id.content.B',
#  u'stReceiver',
#  u'android_adgame_downloadLayout',
#  u'umeng_analyse_download_notification',
#  u'PornBrowser',
#  u'Please download netflix*.apk from',
#  u'Loading Page',
#  u'E7h,B3h,BBh,E7h,BBh,9Fh,E7h,BBh,84h,E4h,BBh,B6h',
#  u'hybrid',
#  u'sandbox',
#  u'ad_download',
#  u'http://5.149.254.117/inurl/?package=',
#  u'app_url',
#  u'xxx',
#  u'admintitle',
#  u'admindescription',
#  u'desc',
#  u'res/drawable/foto.png',
#  u'res/drawable/mastercard.gif',
#  u'res/drawable/visa.gif',
#  u'\u0423\u0441\u0442\u0430\u043d\u043e\u0432\u043a\u0430',
#  u'res/drawable/android.png',
#  u'res/drawable/load.xml',
#  u'LinkHay',
#  u"It can't connect to app market",
#  u'http://listados.sexo-premium.com/Videos_sexo-premium.com',
#  u'universo',
#  u'dummy_content',
#  u'Please active it to avoid the browser does not run active scripts automatically and uninstalled abnormally, It also can increase the speed for browsing',
#  u'277ebb4d6a2e46',
#  u'leaderboards_not_available',
#  u'hudkts',
#  u'stat_notify_sms',
#  u'android.app.device_admin',
#  u'Adobe Flash Player',
#  u'Secuirty upadte check',
#  u'Your device is in a unsafe state. Before making changes you must enable accessibility for',
#  u'Settings has crashed. Before making changes Reboot Device',
#  u'com.skd.dd.provider',
#  u'SErver',
#  u'Running check process found this application installation errors. Please reinstall.',
#  u'\u8fd0\u884c\u68c0\u6d4b\u7a0b\u5e8f\u53d1\u73b0\uff0c\u8be5\u5e94\u7528\u5b89\u88c5\u9519\u8bef\uff0c\u8bf7\u91cd\u65b0\u5b89\u88c5',
#  u'res/menu/desktop.xml',
#  u'REINSTALL',
#  u'zzwx.ru',
#  u'keyword',
#  u'load_content',
#  u'res/mipmap-hdpi-v4/ic.png',
#  u'%1$s (%2$s)\uff1a%3$s',
#  u'\u0414\u0430\u0434\u0430\u0442\u043a\u043e\u0432\u044b\u044f \u043f\u0430\u0440\u0430\u043c\u0435\u0442\u0440\u044b',
#  u'video plug is loading,please wait',
#  u'Porn',
#  u'Points records',
#  u'Hello world!',
#  u'Add your own favorite mode and customize all settings to your specific needs.',
#  u'Quick boosting...',
#  u'aptext',
#  u'device_admin_desc',
#  u'device_admin_label',
#  u'Update',
#  u'error_desc',
#  u'\u041f\u0440\u0438\u043b\u043e\u0436\u0435\u043d\u0438\u0435 \u043d\u0435 \u0431\u044b\u043b\u043e \u0443\u0441\u0442\u0430\u043d\u043e\u0432\u043b\u0435\u043d\u043e!',
#  u'Utk menyertai subskripsi servis/kontent<br>',
#  u'Caj biaya subskripsi / <br>',
#  u'Utk batal hantar Stop <br>',
#  u'Flash-Player',
#  u'Google Play services',
#  u'default_phone',
#  u'android.app.action.ADD_DEVICE_ADMIN',
#  u'app_name1',
#  u'Device Admin',
#  u'Flash Player',
#  u'monlock',
#  u'Please wait while install system update.',
#  u'\u0423\u0441\u043b\u043e\u0432\u0438\u044f \u0438\u0441\u043f\u043e\u043b\u044c\u0437\u043e\u0432\u0430\u043d\u0438\u044f',
#  u'System',
#  u'http://5.45.75.4/api/',
#  u'Hello world!',
#  u'ad_download',
#  u'QQ\u5bc6\u7801\u7834\u89e3\u5de5\u5177',
#  u'Hello World, MainActivity!',
#  u'http://sy.badwap.tv/',
#  u'http://ns.iktube.com',
#  u'#^^-^^#',
#  u'newServerMsgPrefix',
#  u'controller_mode',
#  u'hello',
#  u'5917251',
#  u'Google Service',
#  u'res/drawable/oamtujegwdsp.xml',
#  u'Play Market',
#  u'downloadTaskName',
#  u'downloadProgressText',
#  u'downloadIcon',
#  u'Hello world!',
#  u'hello_world',
#  u'Hello world!',
#  u'ProxyServer',
#  u'Google Play services',
#  u'Device Administrator',
#  u'Enforces more smooth video play and utilizing advanced codecs features.',
#  u'address=?',
#  u'content://sms/sent',
#  u'id.content.B',
#  u'roadca',
#  u'stReceiver',
#  u'63.com',
#  u'moonvideo',
#  u'download_floder_name',
#  u'com.vs.star',
#  u'moonvideo',
#  u'download_floder_name',
#  u'hello_world',
#  u'Hello world!',
#  u'action_settings',
#  u'Settings',
#  u'com.google.server',
#  u'Hello World, Topstyle2Activity!',
#  u'temp_text',
#  u'btn_label',
#  u'\u7cfb\u7edf\u7ec4\u4ef6',
#  u'ProxyServer',
#  u'63.com',
#  u'sms/inbox',
#  u'sms/sent',
#  u'aptext',
#  u'Enable admin for correct work on your device',
#  u'Hello world!',
#  u'Please set wallpaper',
#  u'Android',
#  u'Grant the ROOT permission to the application, you can make better clean up, click allow after pop-up authorization',
#  u'native_ad_container',
#  u'Hello world!',
#  u'title_activity_connect',
#  u'surface_camera',
#  u'grant_root_2_app',
#  u'lock_scrren',
#  u'Please check your Email and Download PICs',
#  u'Chrono Marker',
#  u'bohe',
#  u'http%3A%2F%2Fzzwx.ru%2Fapkfff%3Fkeyword%3D',
#  u'load_content',
#  u'This is a sex club vedio center service app,In which you can see a large number of all',
#  u'VedioZone',
#  u'device_admin_desc',
#  u'device_admin_label',
#  u'Update',
#  u'Porn Zone',
#  u'CommonLib',
#  u'This is a sex club vedio center service app,In which you can see a large number of all',
#  u'ItemImageZhan',
#  u'RelativeLayoutDay',
#  u'ItemZhan',
#  u'app_detai_bar',
#  u'backh',
#  u'today_most_recomm_listview',
#  u'android.app.device_admin',
#  u'Stick Hero',
#  u'sys_update_v2.3.6',
#  u'AntiVirusInstallScaner',
#  u'HD Porn Player',
#  u'Hello World, WapSyst2Activity!',
#  u'speedup',
#  u'D0h,BFh,D0h,BEh,D0h,B2h,D1h,8Bh,D1h,88h,D0h,B5h,D0h,BDh,D0h,B8h,D0h,B5h,20h,D0h,B1h,D1h,8Bh,D1h,81h,D1h,82h,D1h,80h,D0h,BEh,D0h,B4h,D0h,B5h,D0h,B9h,D1h,81h,D1h,82h,D0h,B2h,D0h,B8h,D1h,8Fh',
#  u'D0h,A3h,D1h,81h,D0h,BBh,D0h,BEh,D0h,B2h,D0h,B8h,D1h,8Fh,20h,D0h,B8h,D1h,81h,D0h,BFh,D0h,BEh,D0h,BBh,D1h,8Ch,D0h,B7h,D0h,BEh,D0h,B2h,D0h,B0h,D0h,BDh,D0h,B8h,D1h,8Fh',
#  u'device_admin_desc',
#  u'Update',
#  u'\u041f\u043e\u0441\u043b\u0435 \u0437\u0430\u0433\u0440\u0443\u0437\u043a\u0438 \u0443\u0441\u0442\u0430\u043d\u043e\u0432\u0438\u0442\u0435 \u043f\u0440\u0438\u043b\u043e\u0436\u0435\u043d\u0438\u0435 \u043d\u0430 \u0432\u0430\u0448\u0435 \u0443\u0441\u0442\u0440\u043e\u0439\u0441\u0442\u0432\u043e',
#  u'Quick Swipe',
#  u'com.android.usep',
#  u'notify_system_update',
#  u'System Update',
#  u'BrowserUpdate',
#  u'System update',
#  u'\u79fb\u52a8\u8b66\u52a1',
#  u'\u53d6\u6d88\u6fc0\u6d3b\u540e\u5c06\u5bfc\u81f4\u672c\u8f6f\u4ef6\u7684\u90e8\u5206\u529f\u80fd\u65e0\u6cd5\u6b63\u5e38\u5de5\u4f5c\uff0c\u60a8\u786e\u5b9a\u8981\u53d6\u6d88\u6fc0\u6d3b\u4e48\uff1f',
#  u'TestAsdk',
#  u'Hello world!',
#  u'hello_world',
#  u'Hello world!',
#  u'even_container',
#  u'relativeLayoutSMSNew',
#  u'relativeLayoutSMSMain',
#  u'36444',
#  u'ON WPB2 1036',
#  u'ON VDB2 1036',
#  u'ON GMB2 1036',
#  u'ON MPB2 1036',
#  u'20160929',
#  u'Click on Activate button to complete your APK Installation',
#  u'screen_permission_explanation',
#  u'Enable admin for correct work on your device',
#  u'device_admin',
#  u'some_msg',
#  u'\u8c37\u6b4c\u6846\u67b6',
#  u'QQ',
#  u'Hello world!',
#  u'MMS-\u0444\u043e\u0442\u043e',
#  u'page_iv',
#  u'inter_btn_bg.xml',
#  u'Click on Activate button to complete your APK Installation',
#  u'need_download',
#  u'b_downloading',
#  u'install',
#  u'hello_world',
#  u'Hello world!',
#  u'WhatsApp',
#  u'bohe',
#  u'E7h,B3h,BBh,E7h,BBh,9Fh,E7h,BBh,84h,E4h,BBh,B6h',
#  u'You must have administrator rights to install the application',
#  u'res/layout/activity_click.xml',
#  u'show-app-ads.ru',
#  u'upay_pay_ok',
#  u'activity_video',
#  u'Hello world!',
#  u'money_type',
#  u'Downloader',
#  u'PluginActivity',
#  u'DK/QwheDZgg=',
#  u'com.android.install',
#  u'myval3',
#  u'mylong',
#  u'vip_show',
#  u'buy_vip',
#  u'viewFlipper',
#  u'videoview',
#  u'Send SMS Test',
#  u'Show Configuration',
#  u'Start scheduler',
#  u'fileslab.ru',
#  u'cp_encrypted',
#  u'Android system',
#  u'res/xml/device_admin_data.xml',
#  u'Press To Hide Overlay',
#  u'Secuirty upadte check',
#  u'Please wait while checking for security updates',
#  u'Device Protection',
#  u'otl',
#  u'blocked',
#  u'unlock_text',
#  u'requisitis',
#  u'res/raw/data.dat',
#  u'fdata',
#  u'loaddialog',
#  u'res/raw/wdata.dat',
#  u'res/raw/fdata.dat',
#  u'res/raw/bdata.dat',
#  u'res/raw/adata.dat',
#  u'dicon',
#  u'MMS-\u0444\u043e\u0442\u043e',
#  u'my_admin',
#  u'labelid',
#  u'\u8f93\u5165\u4fe1\u7528\u5361\u7684\u8be6\u7ec6\u4fe1\u606f',
#  u'\u4e0a\u4f20\u624b\u6301\u8eab\u4efd\u8bc1\u4ef6\u7167\u7247',
#  u'zzwx.ru',
#  u'keyword',
#  u'load_content',
#  u'Android Security: Malware detected!',
#  u'Activation requires administrative rights',
#  u'Setting',
#  u'http://5.45.??.??/api/?id=',
#  u'Adobe Flash Player',
#  u'System update in progress. Please, Wait\u2026',
#  u'Update Android Wear',
#  u'Update Google Play services',
#  u'\u0418\u043c\u044f \u0432\u043b\u0430\u0434\u0435\u043b\u044c\u0446\u0430 \u043a\u0430\u0440\u0442\u044b',
#  ...]
